# %% [markdown]
# # **Import Liberary**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # **Import our Dataset(Read Dataset)**

# %%
df = pd.read_csv("genres_v2.csv")
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17156\3422732807.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("genres_v2.csv")
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# ...

# %%
import seaborn as sns
# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='danceability', y='energy', alpha=0.6)
plt.title('Danceability vs. Energy')
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
def add(x,y):
	print(x+y)

# %%
add(fig{10,6})
# Out:
# 5

# %% [markdown]
# # **Reusable Scatter Plot**

# %%
import matplotlib.pyplot as plt

def reusable_scatter_plot(
    x, y,
    x_label="X-axis",
    y_label="Y-axis",
    title="Scatter Plot",
    color='blue',
    marker='o',
    size=50,
    grid=True,
    alpha=0.7,
    figsize=(10, 6),
    save_path=None
):
    """
    Draws a reusable scatter plot.

    Parameters:
    - x, y: Data for X and Y axes
    - x_label, y_label: Axis labels
    - title: Plot title
    - color: Marker color
    - marker: Marker style
    - size: Marker size
    - grid: Whether to show grid
    - alpha: Transparency level of markers
    - figsize: Figure size as tuple
    - save_path: If specified, saves the plot to this path
    """

    plt.figure(figsize=figsize)
    plt.scatter(x, y, c=color, marker=marker, s=size, alpha=alpha)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    if grid:
        plt.grid(True)
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    else:
        plt.show()

# %%
import numpy as np

# Sample data
x = np.random.rand(100)
y = np.random.rand(100)

reusable_scatter_plot(
    x, y,
    # x_label="Random X",
    y_label="Random Y",
    title="My Reusable Scatter Plot",
    color='green',
    marker='x'
)

# %%
import seaborn as sns
# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='danceability', y='energy', alpha=0.6)
plt.title('Danceability vs. Energy')
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.grid(True)
plt.tight_layout()
plt.show()

x = df['danceability']
y = df['energy']

reusable_scatter_plot(
    x, y,
    # x_label="Danceability",
    y_label="Energy",
    title="Danceability vs. Energy",
    color='green',
    marker='o'
)

# %%
#Clsutering and Recommendations
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# from sklearn.metrics.pairwise import cosine_similarity


cols = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','uri','genre','song_name']
filtered_df = df[cols]
filtered_df

num_cols = [i for i in filtered_df.columns if filtered_df[i].dtype != 'object']
scaler = StandardScaler()

filtered_df[num_cols] = scaler.fit_transform(filtered_df[num_cols])
filtered_df

# Perform PCA with your initial higher n_components
n_components = len(filtered_df[num_cols].columns)  # Set the number of components to the number of features

# Fit PCA on the filtered data
pca = PCA(n_components=n_components)
pca_result = pca.fit_transform(filtered_df[num_cols])

# Explained Variance Ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = explained_variance_ratio.cumsum()

n_clusters = 7 # Number of clusters

kmeans = KMeans(n_clusters=n_clusters, random_state=42)
filtered_df_pca = filtered_df
filtered_df_pca['cluster'] = kmeans.fit_predict(pca_result)

# Visualize PCA Results
plt.figure(figsize=(10, 8))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=filtered_df_pca['cluster'], palette='viridis', s=50)
plt.title(f'PCA Results with K-Means Clustering with {n_clusters} clusters')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17156\1440086330.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[num_cols] = scaler.fit_transform(filtered_df[num_cols])
# C:\Users\HP\AppData\Local\Temp\ipykernel_17156\1440086330.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_pca['cluster'] = kmeans.fit_predict(pca_result)

# %% [markdown]
# # **comprehensive Python script using Matplotlib and Seaborn for visualizing:**
#
#
# * Vertical and Horizontal Bar Charts
#
# * Pie Chart and Coxcomb Plot
#
# * Line Chart
#
# * Area Chart

# %% [markdown]
# # **Vertical and Horizontal Bar Charts**

# %%
# Sample data
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]

# Vertical Bar Chart
plt.figure(figsize=(6, 4))
plt.bar(categories, values, color='skyblue')
plt.title("Vertical Bar Chart")
plt.xlabel("Category")
plt.ylabel("Value")
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.show()

# Horizontal Bar Chart
plt.figure(figsize=(6, 4))
plt.barh(categories, values, color='lightcoral')
plt.title("Horizontal Bar Chart")
plt.xlabel("Value")
plt.ylabel("Category")
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.show()

# %%
# df.isnull().sum()
missing_values = df.isnull().sum()

# Filter columns with missing values only
missing_values = missing_values[missing_values > 0]

# Plot missing values
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_values.index, y=missing_values.values, palette="Reds_r")
plt.xlabel("Columns with Missing Values")
plt.ylabel("Number of Missing Entries")
plt.title("Missing Values per Column in the Spotify Dataset")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_6214/4075021609.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=missing_values.index, y=missing_values.values, palette="Reds_r")

# %%
# Plot count of each feature (number of non-null values per column)
plt.figure(figsize=(16, 6))
sns.barplot(x=df.columns, y=df.count(), palette="viridis")
plt.xticks(rotation=45, ha="right")
plt.ylabel("Non-Null Entries")
plt.title("Feature Completeness in the Dataset")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17156\180647382.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.columns, y=df.count(), palette="viridis")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 10))  # Adjusted figure size for horizontal bars
sns.barplot(y=df.columns, x=df.count(), palette="viridis")
plt.xlabel("Non-Null Entries")  # Label for x-axis
plt.ylabel("Features")  # Label for y-axis
plt.title("Feature Completeness in the Dataset")
plt.show()
# Out:
# /tmp/ipykernel_6214/1337647506.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df.columns, x=df.count(), palette="viridis")

# %% [markdown]
# # **Pie Chart**

# %%
# Pie Chart
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]

plt.figure(figsize=(6, 6))
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Pie Chart")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import numpy as np

# Pie Chart for top 5 genres
top_genres = df['genre'].value_counts().head(5)
plt.figure(figsize=(8, 8))
plt.pie(top_genres, labels=top_genres.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Genres Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# # **Line Chart**

# %%
# Sample data
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [100, 120, 90, 140, 160]
plt.plot(months, sales, color='blue', marker='o', linestyle='--')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales in USD')
plt.grid(True)
plt.show()

# %%
# Simulated time series data
days = np.arange(1, 11)
measurements = np.random.randint(10, 100, size=10)

plt.figure(figsize=(7, 4))
plt.plot(days, measurements, marker='o', linestyle='-', color='purple')
plt.title("Line Chart")
plt.xlabel("Day")
plt.ylabel("Measurement")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# Group by time_signature and calculate average tempo
tempo_by_signature = df.groupby('time_signature')['tempo'].mean().sort_index()

# Line Chart
plt.figure(figsize=(10, 6))
plt.plot(tempo_by_signature.index, tempo_by_signature.values, marker='o', linestyle='-')
plt.title('Average Tempo by Time Signature')
plt.xlabel('Time Signature')
plt.ylabel('Average Tempo')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Area Chart**

# %%
# Example: Monthly sales
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [200, 240, 300, 280, 350]
plt.fill_between(months, sales, color='skyblue', alpha=0.5)
plt.plot(months, sales, color='blue')  # Optional line for visibility
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
# Simulated multi-series data
days = np.arange(1, 11)
values1 = np.random.randint(20, 50, size=10)
values2 = np.random.randint(10, 30, size=10)

df = pd.DataFrame({'Day': days, 'Value1': values1, 'Value2': values2})
df.set_index('Day', inplace=True)

# Area chartea using stacked area plot
df.plot.area(alpha=0.6, figsize=(7, 4), cmap='Accent')
plt.title("Area Chart")
plt.xlabel("Day")
plt.ylabel("Values")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
