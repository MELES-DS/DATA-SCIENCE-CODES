# %%
#importing csv files
import pandas as pd
# Method 1 for CSV file (raw string)
df1 = pd.read_csv(r"C:\Users\Student\Downloads\three_page_simulated.csv")
print("========== Method 1 Output ==========")
print(df1)
print("\n" + "="*40 + "\n")

# Method 2 for CSV file (double backslashes)
df2 = pd.read_csv("C:\\Users\\Student\\Downloads\\three_page_simulated.csv")
print("========== Method 2 Output ==========")
print(df2)
print("\n" + "="*40 + "\n")

# Method 3 for CSV file (forward slashes)
df3 = pd.read_csv("C:/Users/Student/Downloads/three_page_simulated.csv")
print("========== Method 3 Output ==========")
print(df3)
print("\n" + "="*40 + "\n")
# Out:
# ========== Method 1 Output ==========
#     Page  ID    Name  Age  Grade
# 0      1   1     Ali   14      8
# 1      1   2    Sara   15      9
# 2      1   3    John   13      7
# 3      1   4     Nia   14      8
# 4      1   5     Leo   15      9
# 5      2   6    Emma   12      6
# 6      2   7    Liam   13      7
# 7      2   8     Ava   14      8
# 8      2   9    Noah   15      9
# 9      2  10     Zoe   13      7
# 10     3  11     Max   14      8
# 11     3  12    Isla   12      6
# 12     3  13  Jayden   13      7
# 13     3  14    Ella   15      9
# 14     3  15    Milo   14      8
#
# ...
#
# ========== Method 2 Output ==========
#     Page  ID    Name  Age  Grade
# 0      1   1     Ali   14      8
# 1      1   2    Sara   15      9
# 2      1   3    John   13      7
# 3      1   4     Nia   14      8
# 4      1   5     Leo   15      9
# 5      2   6    Emma   12      6
# 6      2   7    Liam   13      7
# 7      2   8     Ava   14      8
# 8      2   9    Noah   15      9
# ...

# %%
#importing excel flies
import pandas as pd
# Method 1: Forward slashes (BG: Yellow)
df1 = pd.read_excel("C:/Users/Student/Downloads/simple_excel_file.xlsx")
print("\n" + "\033[43m" + "="*50 + "\033[0m")
print("\033[43mMethod 1 Output (Forward Slashes)\033[0m")
print("\033[43m{}\033[0m".format(df1.to_string(index=False)))
print("\033[43m" + "="*50 + "\033[0m\n")

# Method 2: Double backslashes (BG: Cyan)
df2 = pd.read_excel("C:\\Users\\Student\\Downloads\\simple_excel_file.xlsx")
print("\n" + "\033[46m" + "="*50 + "\033[0m")
print("\033[46mMethod 2 Output (Double Backslashes)\033[0m")
print("\033[46m{}\033[0m".format(df2.to_string(index=False)))
print("\033[46m" + "="*50 + "\033[0m\n")

# Method 3: Corrected version (BG: Magenta)
df3 = pd.read_excel("C:/Users/Student/Downloads/simple_excel_file.xlsx")
print("\n" + "\033[45m" + "="*50 + "\033[0m")
print("\033[45mMethod 3 Output (Corrected Version)\033[0m")
print("\033[45m{}\033[0m".format(df3.to_string(index=False)))
print("\033[45m" + "="*50 + "\033[0m\n")
# Out:
# ...
# Method 1 Output (Forward Slashes)
#  ID    Name  Age        City
#   1   Alice   25    New York
#   2     Bob   30 Los Angeles
#   3 Charlie   35     Chicago
# ...
#
#
# ...
# Method 2 Output (Double Backslashes)
#  ID    Name  Age        City
#   1   Alice   25    New York
#   2     Bob   30 Los Angeles
#   3 Charlie   35     Chicago
# ...
#
#
# ...
# Method 3 Output (Corrected Version)
#  ID    Name  Age        City
#   1   Alice   25    New York
#   2     Bob   30 Los Angeles
#   3 Charlie   35     Chicago
# ...

# %%
import chardet
import zipfile

# Path to your ZIP file
zip_path = "C:/Users/Student/Downloads/simple_zip_file.zip"

# Open the ZIP file and read the first few bytes of the CSV file
with zipfile.ZipFile(zip_path, 'r') as z:
    # List all files in the ZIP archive
    file_list = z.namelist()
    # Assuming the first file is the CSV you want
    with z.open(file_list[0]) as f:
        raw_data = f.read(10000)  # Read the first 10,000 bytes

# %%
import numpy as np
# Sample data
x = np.linspace(-2, 10, 100)
y = np.sin(x)
# Sequential color scale
plt.scatter(x, y, c=y, cmap='Blues')
plt.colorbar(label='Value')
plt.title('Color to Represent Data Values')
plt.show()

# %%
x = np.linspace(2, 1, 200)
y = np.sin(2 * np.pi * x)
# Create a scatter plot with a nonmonotonic color scale
plt.scatter(x, y, c=y, cmap="twilight", edgecolor="black")
plt.colorbar(label="Nonmonotonic Scale")
plt.title("Nonmonotonic Color Scale Example")
plt.show()
