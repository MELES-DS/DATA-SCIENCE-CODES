# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Replace these with your actual 100 values
age = [
    22, 24, 23, 25, 27, 28, 30, 32, 35, 36, 37, 38, 39, 40, 41, 43, 44, 45, 46, 47,
    48, 49, 50, 52, 53, 54, 55, 56, 57, 58, 59, 60, 62, 63, 64, 65, 66, 67, 68, 69,
    70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 22, 24, 26, 28, 29, 30, 32, 33, 35,
    36, 38, 39, 41, 43, 45, 46, 47, 49, 50, 52, 53, 54, 56, 57, 59, 60, 61, 63, 65,
    66, 67, 69, 70, 71, 73, 74, 75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88
]

salary = [
    2000, 2200, 2100, 2500, 2600, 2800, 2900, 3000, 3200, 3300, 3400, 3500, 3600, 3800, 4000, 4200, 4300, 4400, 4500, 4600,
    4700, 4800, 5000, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 6000, 6200, 6400, 6600, 6700, 6800, 7000, 7200, 7400, 7600,
    7800, 8000, 8200, 8400, 8600, 8800, 9000, 9200, 9400, 9600, 9800, 2300, 2400, 50000, 2600, 2700, 2800, 2900, 3000, 3100,
    3200, 3400, 3600, 3800, 4000, 4200, 4300, 4500, 4600, 4700, 4900, 5000, 5200, 5400, 5600, 5800, 6000, 6200, 6400, 6600,
    6800, 7000, 7200, 7400, 7600, 7800, 8000, 8200, 8400, 8600, 8800, 9000, 9200, 9400, 9600, 9800, 10000, 10500, 11000, 12000
]

df = pd.DataFrame({'Age': age, 'Salary': salary})

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Salary')
plt.title("Age vs Salary (100 Manual Values)")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.grid(True)
plt.show()

# %%
# Plot
plt.figure(figsize=(15, 6))
sns.barplot(x=df.index, y='Salary', data=df, palette='viridis')

plt.title('Salary of Individuals')
plt.xlabel('Person Index')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")
print(f"Min Salary: {df['Salary'].min()}")
print(f"Max Salary: {df['Salary'].max()}")
# Out:
# Lower Bound: -2400.0
# Upper Bound: 14000.0
# Min Salary: 2000
# Max Salary: 50000

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Salary'] < lower_bound) | (df['Salary'] > upper_bound)]
print("Outliers:\n", outliers)
# Out:
# Outliers:
#      Age  Salary
# 53   26   50000

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Age', 'Salary']], palette='Set2')
plt.title("Box Plot of Age and Salary")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.scatter(outliers['Age'], outliers['Salary'], color='red', label='Outliers')
plt.title("Scatter Plot with Outliers")
plt.legend()
plt.grid(True)
plt.show()
